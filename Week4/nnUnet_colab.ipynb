# %%
# !pip install -U nnunetv2
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 kB 18.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 10.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 5.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 MB 17.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.7/24.7 MB 67.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 109.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 kB 12.4 MB/s eta 0:00:00
# ...

# %%
# !rm -rf /content/nnUNet* /content/Task04* /content/nnunet* 2>/dev/null || true

# %%
import sys
print("Python:", sys.executable)

# !{sys.executable} -c "import nnunetv2; print('nnUNet v2 OK')"
# Out:
# Python: /usr/bin/python3
# nnUNet v2 OK

# %%
import os

os.environ["nnUNet_raw"] = "/content/nnUNet_raw"
os.environ["nnUNet_preprocessed"] = "/content/nnUNet_preprocessed"
os.environ["nnUNet_results"] = "/content/nnUNet_results"

# !mkdir -p /content/nnUNet_raw
# !mkdir -p /content/nnUNet_preprocessed
# !mkdir -p /content/nnUNet_results

# %%
# !tar -xf /content/Task04_Hippocampus.tar
# !ls /content/Task04_Hippocampus
# Out:
# dataset.json  imagesTr	imagesTs  labelsTr

# %%
# !nnUNetv2_convert_MSD_dataset \
  -i /content/Task04_Hippocampus \
  -overwrite_id 4

# %%
# !ls /content/nnUNet_raw
# !ls /content/nnUNet_raw/Dataset004_Hippocampus
# Out:
# Dataset004_Hippocampus
# dataset.json  imagesTr	imagesTs  labelsTr

# %%
# !nnUNetv2_plan_and_preprocess -d 4
# Out:
# Fingerprint extraction...
# Dataset004_Hippocampus
# Using <class 'nnunetv2.imageio.simpleitk_reader_writer.SimpleITKIO'> as reader/writer
# 100% 260/260 [00:23<00:00, 11.25it/s]
# Experiment planning...
#
# ############################
# INFO: You are using the old nnU-Net default planner. We have updated our recommendations. Please consider using those instead! Read more here: https://github.com/MIC-DKFZ/nnUNet/blob/master/documentation/resenc_presets.md
# ############################
#
# Dropping 3d_lowres config because the image size difference to 3d_fullres is too small. 3d_fullres: [36. 50. 35.], 3d_lowres: [36, 50, 35]
# 2D U-Net configuration:
# ...

# %%
# !pip install hiddenlayer
# Then restart training (optional, not required)

# %%
# !nnUNetv2_train 4 2d 0 -device cuda
# Out:
# ############################
# INFO: You are using the old nnU-Net default plans. We have updated our recommendations. Please consider using those instead! Read more here: https://github.com/MIC-DKFZ/nnUNet/blob/master/documentation/resenc_presets.md
# ############################
#
# Using device: cuda:0
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 2026-01-14 14:43:25.805440: Using torch.compile...
# 2026-01-14 14:43:29.189922: do_dummy_2d_data_aug: False
# 2026-01-14 14:43:29.190791: Creating new 5-fold cross-validation split...
# 2026-01-14 14:43:29.193068: Desired fold for training: 0
# ...

# %%
# !ls /content/nnUNet_results/Dataset004_Hippocampus/nnUNetTrainer__nnUNetPlans__2d/fold_0

# %%
# !zip -r /content/nnUNetv2_Task04_model.zip \
/content/nnUNet_results/Dataset004_Hippocampus

# %%
from google.colab import files
files.download("/content/nnUNetv2_Task04_model.zip")
